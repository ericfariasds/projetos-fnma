# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('projetos-fnma-1990-a-2024-dados-abertos-2025.csv', sep=None, engine='python')
df.columns = df.columns.str.strip()
df = df.rename(columns={df.columns[0]: 'Ano'})
df['Região Geográfica'] = df['Região Geográfica'].str.strip()
df.head()
# Out:
#     Ano Nº do Instrumento de Repasse Nº  Interno  \
# 0  1990                          NaN    CV001/90
# 1  1990                          NaN    CV002/90
# 2  1990                          NaN    CV003/90
# 3  1990                          NaN    CV004/90
# 4  1990                          NaN    CV005/90
#
#                                      Tema  \
# 0                      Educação Ambiental
# 1              Gestão de Áreas Protegidas
# 2  Conservação e Manejo da Biodiversidade
# 3              Gestão de Áreas Protegidas
# 4                    Amazônia Sustentável
#
#                                Instituição Executora  \
# 0                 Fundação Nacional do Índio - Funai
# 1  Núcleo de Cultura Indígena da União das Nações...
# 2                   Fundação Pró-natureza – Funatura
# 3  Núcleo de Cultura Indígena da União das Nações...
# 4                 Prefeitura Municipal de Curralinho
#
#                                    Título do Projeto  UF Região Geográfica  \
# 0            I Encontro sobre Meio Ambiente Indígena  DF      Centro-Oeste
# 1  Serra do Roncador/Xavante: Manejo Indígena de ...  GO      Centro-Oeste
# 2                Conservação da Avifauna da Amazônia  DF      Centro-Oeste
# 3  Metareilá/Suruí: Manejo Indígena de Floresta T...  GO      Centro-Oeste
# 4  Extensão Florestal e Pesquisa nas Áreas das Fl...  AM             Norte
#
#   Cidade da Instituição Executora      Bioma Esfera Institucional  \
# 0                             NaN    Cerrado              Federal
# 1                             NaN  Cerrado                    OSC
# 2                             NaN  Amazônia                   OSC
# 3                             NaN  Amazônia                   OSC
# 4                             NaN  Amazônia             Municipal
#
#   Data Assinatura Data de Publicação no DOU Data de Fim da Vigência  \
# 0      07/12/1990                       NaN              31/12/1990
# 1      14/11/1990                       NaN              31/12/1990
# 2      13/11/1990                       NaN              31/12/1990
# 3      14/11/1990                       NaN              31/12/1990
# 4      13/11/1990                22/11/1990              31/12/1990
#
#   Recursos do FNMA (R$) Recursos de CP (R$) Valor Total do Projeto (R$)  \
# 0              2.837,01                   0                    2.837,01
# 1             41.212,07                   0                   41.212,07
# 2             22.907,20                   0                   22.907,20
# 3             88.484,75                   0                   88.484,75
# 4            304.654,39                   0                  304.654,39
#
#   Tipo de Seleção do Projeto  \
# 0    Demanda Espontânea (DE)
# 1    Demanda Espontânea (DE)
# 2    Demanda Espontânea (DE)
# 3    Demanda Espontânea (DE)
# 4    Demanda Espontânea (DE)
#
#   Edital ou Termo de Referência de Origem do Projeto
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
print(f"Total de linhas: {len(df)}")
print(f"Total de colunas: {len(df.columns)}")
print(f"Colunas: {list(df.columns)}")
# Out:
# Total de linhas: 1495
# Total de colunas: 19
# Colunas: ['Ano', 'Nº do Instrumento de Repasse', 'Nº  Interno', 'Tema', 'Instituição Executora', 'Título do Projeto', 'UF', 'Região Geográfica', 'Cidade da Instituição Executora', 'Bioma', 'Esfera Institucional', 'Data Assinatura', 'Data de Publicação no DOU', 'Data de Fim da Vigência', 'Recursos do FNMA (R$)', 'Recursos de CP (R$)', 'Valor Total do Projeto (R$)', 'Tipo de Seleção do Projeto', 'Edital ou Termo de Referência de Origem do Projeto']

# %%
por_ano = df.groupby('Ano').size().reset_index(name='Projetos')

px.bar(por_ano, x='Ano', y='Projetos',
       title='Projetos por ano',
       color='Projetos',
       color_continuous_scale='Blues')

# %%
por_tema = df['Tema'].value_counts().reset_index()
por_tema.columns = ['Tema', 'Projetos']
por_tema = por_tema.sort_values('Projetos')

px.bar(por_tema, x='Projetos', y='Tema',
       orientation='h',
       title='Projetos por tema',
       color='Projetos',
       color_continuous_scale='Teal')

# %%
regiao = 'Norte'  # mude aqui para explorar

df_filtrado = df[df['Região Geográfica'] == regiao]
por_ano_filtrado = df_filtrado.groupby('Ano').size().reset_index(name='Projetos')

px.bar(por_ano_filtrado, x='Ano', y='Projetos',
       title=f'Projetos por ano — Região {regiao}',
       color='Projetos',
       color_continuous_scale='Greens')
